# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import torch
import uuid
import os
import time

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /home/maxpasit/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2021-11-22 torch 1.7.0 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6075MiB)
# ...
# 100%|██████████| 14.0M/14.0M [00:02<00:00, 5.19MB/s]
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): Model(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (2): C3(
#         (cv1): Conv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
# ...

# %%
img = 'https://ultralytics.com/images/zidane.jpg'

# %%
results = model(img)
results.print()
results.show()
# Out:
# image 1/1: 720x1280 2 persons, 1 tie
# Speed: 1235.6ms pre-process, 11.3ms inference, 5.0ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()

    results = model(frame)
    cv2.imshow('Yolo', np.squeeze(results.render()))

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# python train.py --img 320 --batch 16 --epochs 5 --data dataset.yaml --weight yolov5s.pt

# %% [markdown]
# <h1>Load model</h1>

# %%
model = torch.hub.load('/home/maxpasit/Documents/workspace/yolov5', 'custom', path='/home/maxpasit/Documents/workspace/yolov5/models/hub/best.pt', force_reload=True, source='local')
# Out:
# YOLOv5 🚀 2021-12-6 torch 1.7.0 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6075MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86180143 parameters, 0 gradients, 204.0 GFLOPs
# Adding AutoShape...

# %%
img = '/home/maxpasit/Documents/workspace/FireTraining/images/img (32).jpg'
results = model(img)
results.print()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3930/1383029502.py in <module>
#       1 img = '/home/maxpasit/Documents/workspace/FireTraining/images/img (32).jpg'
# ----> 2 results = model(img)
#       3 results.print()
#
# ~/anaconda3/envs/opencv/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/opencv/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ...

# %%
results.show()

# %%
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture('/home/maxpasit/Documents/workspace/Dataset/VideoFire/fireCar.mp4')
while cap.isOpened():
    ret, frame = cap.read()

    results = model(frame)
    cv2.imshow('Yolo', np.squeeze(results.render()))

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
